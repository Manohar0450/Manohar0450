# %% [markdown]
# <a href="https://colab.research.google.com/github/Manohar0450/Manohar0450/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from types import MethodDescriptorType
import pandas as vk
import numpy as ks
dataset = vk.read_csv("/content/age_salary_dataset.csv")
dataset
# Out:
#      Age   Salary
# 0   50.0  45056.0
# 1   36.0  72482.0
# 2   29.0  87716.0
# 3   42.0  48110.0
# 4   40.0  53773.0
# ..   ...      ...
# 95  58.0  57675.0
# 96  56.0  92733.0
# 97  43.0  84417.0
# 98  48.0  63938.0
# 99  56.0  63664.0
#
# [100 rows x 2 columns]

# %%
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,-1].values
print("independent variables",x)
print(y)
# Out:
# independent variables [[50.]
#  [36.]
#  [29.]
#  [42.]
#  [40.]
#  [44.]
#  [32.]
#  [32.]
#  [45.]
#  [57.]
#  [45.]
#  [24.]
#  [43.]
#  [23.]
#  [45.]
#  [51.]
#  [59.]
#  [23.]
#  [42.]
#  [54.]
#  [33.]
#  [43.]
#  [nan]
#  [48.]
#  [49.]
#  [37.]
#  [36.]
#  [24.]
#  [58.]
#  [28.]
#  [42.]
#  [30.]
#  [39.]
#  [25.]
#  [46.]
#  [nan]
#  [30.]
#  [47.]
#  [23.]
#  [41.]
#  [49.]
#  [28.]
#  [29.]
#  [nan]
#  [35.]
#  [38.]
#  [57.]
#  [25.]
#  [23.]
#  [27.]
#  [25.]
#  [50.]
#  [39.]
#  [47.]
#  [55.]
#  [31.]
#  [57.]
#  [35.]
#  [52.]
#  [36.]
#  [29.]
#  [35.]
#  [44.]
#  [42.]
#  [37.]
#  [39.]
#  [45.]
#  [47.]
#  [46.]
#  [50.]
#  [36.]
#  [22.]
#  [46.]
#  [28.]
#  [30.]
#  [45.]
#  [22.]
#  [29.]
#  [45.]
#  [32.]
#  [38.]
#  [29.]
#  [56.]
#  [56.]
#  [54.]
#  [26.]
#  [49.]
#  [28.]
#  [30.]
#  [29.]
#  [33.]
#  [55.]
#  [54.]
#  [44.]
#  [45.]
#  [58.]
#  [56.]
#  [43.]
#  [48.]
#  [56.]]
# [45056. 72482. 87716. 48110. 53773. 67266. 92992. 57412. 96537. 73270.
# ...

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=ks.nan,strategy="mean")
x=imp.fit_transform(x)
y=y.reshape(-1,1)
y=imp.fit_transform(y)
y=y.reshape(-1)
print(x)
print(y)
# Out:
# [[50.        ]
#  [36.        ]
#  [29.        ]
#  [42.        ]
#  [40.        ]
#  [44.        ]
#  [32.        ]
#  [32.        ]
#  [45.        ]
#  [57.        ]
#  [45.        ]
#  [24.        ]
#  [43.        ]
#  [23.        ]
#  [45.        ]
#  [51.        ]
#  [59.        ]
#  [23.        ]
#  [42.        ]
#  [54.        ]
#  [33.        ]
#  [43.        ]
#  [39.88659794]
#  [48.        ]
#  [49.        ]
#  [37.        ]
#  [36.        ]
#  [24.        ]
#  [58.        ]
#  [28.        ]
#  [42.        ]
#  [30.        ]
#  [39.        ]
#  [25.        ]
#  [46.        ]
#  [39.88659794]
#  [30.        ]
#  [47.        ]
#  [23.        ]
#  [41.        ]
#  [49.        ]
#  [28.        ]
#  [29.        ]
#  [39.88659794]
#  [35.        ]
#  [38.        ]
#  [57.        ]
#  [25.        ]
#  [23.        ]
#  [27.        ]
#  [25.        ]
#  [50.        ]
#  [39.        ]
#  [47.        ]
#  [55.        ]
#  [31.        ]
#  [57.        ]
#  [35.        ]
# ...

# %%
x_df = vk.DataFrame(x, columns=dataset.columns[:-1])
y_df = vk.DataFrame(y, columns=[dataset.columns[-1]])
combined_data = vk.concat([x_df, y_df], axis=1)
print("Combined data is:", combined_data)
# Out:
# Combined data is:      Age   Salary
# 0   50.0  45056.0
# 1   36.0  72482.0
# 2   29.0  87716.0
# 3   42.0  48110.0
# 4   40.0  53773.0
# ..   ...      ...
# 95  58.0  57675.0
# 96  56.0  92733.0
# 97  43.0  84417.0
# 98  48.0  63938.0
# 99  56.0  63664.0
#
# [100 rows x 2 columns]

# %%
combined_df=vk.DataFrame(combined_data,columns=list(dataset.columns))
combined_df.to_excel("/content/combined_data.xlsx",index=False)
print("combined Dataframe",combined_df.head())
# Out:
# combined Dataframe     Age   Salary
# 0  50.0  45056.0
# 1  36.0  72482.0
# 2  29.0  87716.0
# 3  42.0  48110.0
# 4  40.0  53773.0
